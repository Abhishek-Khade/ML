# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("WC_AT.csv")

# %%
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Waist   109 non-null    float64
#  1   AT      109 non-null    float64
# dtypes: float64(2)
# memory usage: 1.8 KB

# %%
df.corr()
# Out:
#           Waist        AT
# Waist  1.000000  0.818558
# AT     0.818558  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
X = df.drop(['AT'],axis=1)
y = df['AT']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,y,random_state=12345,test_size=0.3,shuffle=True)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

# %%
mae = mean_absolute_error(y_test, model.predict(X_test))
mae
# Out:
# 23.33833649552338

# %%
mse = mean_squared_error(y_test, model.predict(X_test))
mse
# Out:
# 987.4462506726385

# %%
rmse = root_mean_squared_error(y_test, model.predict(X_test))
rmse
# Out:
# 31.423657499925728

# %%
r2 = r2_score(y_test,model.predict(X_test))
r2
# Out:
# 0.5803932663745115

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([3.45885939])

# %%
model.intercept_
# Out:
# -215.98148796164242

# %%
model.predict(X)
# Out:
# array([ 42.56825159,  35.1317039 ,  66.95321031,  74.389758  ,
#         42.22236565,  32.53755936,  63.84023685,  72.48738533,
#          3.65608343,  37.20701954,  32.71050233,  43.43296644,
#         36.8611336 ,  57.26840401,  50.35068522,  22.16098118,
#         46.71888286,  40.49293596,  39.28233517,  46.54593989,
#         49.83185632,  63.84023685,  60.38137746,  92.54876981,
#         67.64498219, 102.23357611,  83.55573539,  62.4566931 ,
#         81.48041975,  69.37441188,  72.83327127,  88.74402448,
#         98.08294484,  93.24054169, 136.82217003, 110.88072459,
#         98.77471671, 140.28102942,  60.7272634 ,  57.26840401,
#         72.83327127,  46.89182583,  62.4566931 ,  83.20984945,
#         71.10384158, 154.46235293, 110.18895271, 110.88072459,
#         59.68960558,  58.30606183,  94.62408544,  73.87092909,
#         78.71333224,  45.16239614,  55.19308837,  55.88486025,
#         87.70636666,  82.51807757,  79.75099006,  73.52504315,
# ...

# %%
plt.scatter(df['Waist'],df['AT'],color ='red')
plt.plot(df['Waist'],model.predict(X),color='blue')
plt.scatter(df['Waist'],model.predict(X),color='blue')

mean_arr = np.ones(y.size) *  y.mean()
plt.scatter(df['Waist'],mean_arr,color='green')
plt.plot(df['Waist'],mean_arr,color='green')
